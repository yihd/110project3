# %%
conda activate env_pytorch
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torchvision
# Out:
# Requirement already satisfied: torchvision in /opt/anaconda3/lib/python3.8/site-packages (0.10.0)
# Requirement already satisfied: torch==1.9.0 in /opt/anaconda3/lib/python3.8/site-packages (from torchvision) (1.9.0)
# Requirement already satisfied: pillow>=5.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from torchvision) (7.2.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.8/site-packages (from torchvision) (1.18.5)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.8/site-packages (from torch==1.9.0->torchvision) (3.7.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imports necessary libraries and modules
from itertools import islice
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os 
import pickle
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from random import shuffle
from IPython.display import Image

# %%
# Directory path
os.chdir("..")
#cwd = 'input'

# Hyper Parameters
num_epochs = 3
batch_size = 2
learning_rate = 0.0001
beta = 1

# Mean and std deviation of imagenet dataset. Source: http://cs231n.stanford.edu/reports/2017/pdfs/101.pdf
std = [0.229, 0.224, 0.225]
mean = [0.485, 0.456, 0.406]

# TODO: Define train, validation and models
MODELS_PATH = '~/Desktop/models/'
# TRAIN_PATH = cwd+'/train/'
# VALID_PATH = cwd+'/valid/'
#VALID_PATH = cwd+'/sample/valid/'
TRAIN_PATH = '~/Desktop/train'
TEST_PATH = '~/Desktop/test'

#if not os.path.exists(TRAIN_PATH): os.mkdir(TRAIN_PATH)

# %%
def customized_loss(S_prime, C_prime, S, C, B):
    ''' Calculates loss specified on the paper.'''
    
    loss_cover = torch.nn.functional.mse_loss(C_prime, C)
    loss_secret = torch.nn.functional.mse_loss(S_prime, S)
    loss_all = loss_cover + B * loss_secret
    return loss_all, loss_cover, loss_secret

def denormalize(image, std, mean):
    ''' Denormalizes a tensor of images.'''

    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image

def imshow(img, idx, learning_rate, beta):
    '''Prints out an image given in tensor format.'''
    
    img = denormalize(img, std, mean)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title('Example '+str(idx)+', lr='+str(learning_rate)+', B='+str(beta))
    plt.show()
    return

def gaussian(tensor, mean=0, stddev=0.1):
    '''Adds random noise to a tensor.'''
    
    noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1)
    return Variable(tensor + noise)

# %%
# Preparation Network (2 conv layers)
class PrepNetwork(nn.Module):
    def __init__(self):
        super(PrepNetwork, self).__init__()
        self.initialP3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialP4 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialP5 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalP3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalP4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalP5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())

    def forward(self, p):
        p1 = self.initialP3(p)
        p2 = self.initialP4(p)
        p3 = self.initialP5(p)
        mid = torch.cat((p1, p2, p3), 1)
        p4 = self.finalP3(mid)
        p5 = self.finalP4(mid)
        p6 = self.finalP5(mid)
        out = torch.cat((p4, p5, p6), 1)
        return out

# Hiding Network (5 conv layers)
class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.initialH3 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialH4 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialH5 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalH4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalH5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0))
        
    def forward(self, h):
        h1 = self.initialH3(h)
        h2 = self.initialH4(h)
        h3 = self.initialH5(h)
        mid = torch.cat((h1, h2, h3), 1)
        h4 = self.finalH3(mid)
        h5 = self.finalH4(mid)
        h6 = self.finalH5(mid)
        mid2 = torch.cat((h4, h5, h6), 1)
        out = self.finalH(mid2)
        out_noise = gaussian(out.data, 0, 0.1)
        return out, out_noise

# Reveal Network (2 conv layers)
class RevealNetwork(nn.Module):
    def __init__(self):
        super(RevealNetwork, self).__init__()
        self.initialR3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialR4 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialR5 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalR4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalR5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0))

    def forward(self, r):
        r1 = self.initialR3(r)
        r2 = self.initialR4(r)
        r3 = self.initialR5(r)
        mid = torch.cat((r1, r2, r3), 1)
        r4 = self.finalR3(mid)
        r5 = self.finalR4(mid)
        r6 = self.finalR5(mid)
        mid2 = torch.cat((r4, r5, r6), 1)
        out = self.finalR(mid2)
        return out

# Join three networks in one module
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.m1 = PrepNetwork()
        self.m2 = HidingNetwork()
        self.m3 = RevealNetwork()

    def forward(self, secret, cover):
        x_1 = self.m1(secret)
        mid = torch.cat((x_1, cover), 1)
        x_2, x_2_noise = self.m2(mid)
        x_3 = self.m3(x_2_noise)
        return x_2, x_3

# %%
# Creates net object
net = Net()

# %%
# Creates training set
train_loader = torch.utils.data.DataLoader(
        datasets.ImageFolder(
        TRAIN_PATH,
        transforms.Compose([
        transforms.Scale(256),
        transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ])), batch_size=batch_size, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# Creates test set
test_loader = torch.utils.data.DataLoader(
        datasets.ImageFolder(
        TEST_PATH, 
        transforms.Compose([
        transforms.Scale(256),
        transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ])), batch_size=2, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/torchvision/transforms/transforms.py:310: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   warnings.warn("The use of the transforms.Scale transform is deprecated, " +

# %%
def train_model(train_loader, beta, learning_rate):
    
    # Save optimizer
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    
    loss_history = []
    # Iterate over batches performing forward and backward passes
    for epoch in range(num_epochs):

        # Train mode
        net.train()
        
        train_losses = []
        # Train one epoch
        for idx, train_batch in enumerate(train_loader):

            data, _  = train_batch

            # Saves secret images and secret covers
            train_covers = data[:len(data)//2]
            train_secrets = data[len(data)//2:]
            
            # Creates variable from secret and cover images
            train_secrets = Variable(train_secrets, requires_grad=False)
            train_covers = Variable(train_covers, requires_grad=False)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            train_hidden, train_output = net(train_secrets, train_covers)

            # Calculate loss and perform backprop
            train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output, train_hidden, train_secrets, train_covers, beta)
            train_loss.backward()
            optimizer.step()
            
            # Saves training loss
            #print(train_loss.data)
            train_losses.append(train_loss.data)
            loss_history.append(train_loss.data)
            
            # Prints mini-batch losses
            print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), train_loss.data, train_loss_cover.data, train_loss_secret.data))
    
        #torch.save(net.state_dict(), MODELS_PATH+'Epoch N{}.pkl'.format(epoch+1))
        
        mean_train_loss = np.mean(train_losses)
    
        # Prints epoch average loss
        print ('Epoch [{0}/{1}], Average_loss: {2:.4f}'.format(
                epoch+1, num_epochs, mean_train_loss))
    
    return net, mean_train_loss, loss_history

# %%
net, mean_train_loss, loss_history = train_model(train_loader, beta, learning_rate)
# Out:
# <ipython-input-3-723a443b100a>:29: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1)
# Training: Batch 1/50. Loss of 2.4615, cover loss of 0.8386, secret loss of 1.6228
# Training: Batch 2/50. Loss of 2.5192, cover loss of 1.2214, secret loss of 1.2978
# Training: Batch 3/50. Loss of 2.9544, cover loss of 0.8672, secret loss of 2.0872
# Training: Batch 4/50. Loss of 2.7585, cover loss of 1.9879, secret loss of 0.7707
# Training: Batch 5/50. Loss of 2.9995, cover loss of 1.3532, secret loss of 1.6463
# Training: Batch 6/50. Loss of 2.4008, cover loss of 0.9707, secret loss of 1.4301
# Training: Batch 7/50. Loss of 1.7954, cover loss of 0.8098, secret loss of 0.9856
# Training: Batch 8/50. Loss of 2.3253, cover loss of 1.2094, secret loss of 1.1159
# Training: Batch 9/50. Loss of 1.7730, cover loss of 0.7457, secret loss of 1.0274
# Training: Batch 10/50. Loss of 2.8837, cover loss of 1.2586, secret loss of 1.6251
# Training: Batch 11/50. Loss of 1.8981, cover loss of 1.1695, secret loss of 0.7286
# Training: Batch 12/50. Loss of 2.1496, cover loss of 0.8854, secret loss of 1.2642
# Training: Batch 13/50. Loss of 1.6735, cover loss of 0.9452, secret loss of 0.7283
# Training: Batch 14/50. Loss of 3.2595, cover loss of 1.7987, secret loss of 1.4608
# Training: Batch 15/50. Loss of 1.5053, cover loss of 0.6505, secret loss of 0.8549
# Training: Batch 16/50. Loss of 1.7995, cover loss of 0.5998, secret loss of 1.1997
# Training: Batch 17/50. Loss of 2.1691, cover loss of 1.6643, secret loss of 0.5048
# Training: Batch 18/50. Loss of 2.0704, cover loss of 0.5573, secret loss of 1.5132
# Training: Batch 19/50. Loss of 3.6720, cover loss of 1.0753, secret loss of 2.5967
# Training: Batch 20/50. Loss of 1.7700, cover loss of 0.5321, secret loss of 1.2379
# Training: Batch 21/50. Loss of 2.4523, cover loss of 1.1827, secret loss of 1.2696
# Training: Batch 22/50. Loss of 1.6065, cover loss of 0.4169, secret loss of 1.1896
# Training: Batch 23/50. Loss of 2.9791, cover loss of 2.0483, secret loss of 0.9308
# Training: Batch 24/50. Loss of 1.9626, cover loss of 0.7437, secret loss of 1.2189
# Training: Batch 25/50. Loss of 1.8895, cover loss of 1.1977, secret loss of 0.6918
# Training: Batch 26/50. Loss of 1.1581, cover loss of 0.2380, secret loss of 0.9201
# Training: Batch 27/50. Loss of 1.1597, cover loss of 0.5235, secret loss of 0.6363
# Training: Batch 28/50. Loss of 1.3431, cover loss of 0.4900, secret loss of 0.8531
# Training: Batch 29/50. Loss of 2.5194, cover loss of 0.5735, secret loss of 1.9459
# Training: Batch 30/50. Loss of 1.4999, cover loss of 0.5733, secret loss of 0.9266
# Training: Batch 31/50. Loss of 1.3268, cover loss of 0.2427, secret loss of 1.0841
# Training: Batch 32/50. Loss of 0.9358, cover loss of 0.5363, secret loss of 0.3995
# Training: Batch 33/50. Loss of 2.5299, cover loss of 1.2204, secret loss of 1.3096
# Training: Batch 34/50. Loss of 2.1070, cover loss of 0.5930, secret loss of 1.5140
# Training: Batch 35/50. Loss of 1.3288, cover loss of 0.3109, secret loss of 1.0178
# Training: Batch 36/50. Loss of 1.4114, cover loss of 0.6442, secret loss of 0.7672
# Training: Batch 37/50. Loss of 0.8932, cover loss of 0.3668, secret loss of 0.5264
# Training: Batch 38/50. Loss of 1.0639, cover loss of 0.3200, secret loss of 0.7439
# Training: Batch 39/50. Loss of 2.1257, cover loss of 0.3489, secret loss of 1.7768
# Training: Batch 40/50. Loss of 1.2696, cover loss of 0.1981, secret loss of 1.0716
# Training: Batch 41/50. Loss of 2.2313, cover loss of 1.0025, secret loss of 1.2288
# Training: Batch 42/50. Loss of 1.2522, cover loss of 0.3668, secret loss of 0.8854
# Training: Batch 43/50. Loss of 1.0685, cover loss of 0.5518, secret loss of 0.5167
# Training: Batch 44/50. Loss of 0.8948, cover loss of 0.4596, secret loss of 0.4352
# Training: Batch 45/50. Loss of 2.9026, cover loss of 0.2764, secret loss of 2.6262
# Training: Batch 46/50. Loss of 3.1797, cover loss of 0.2826, secret loss of 2.8970
# Training: Batch 47/50. Loss of 1.4602, cover loss of 0.1939, secret loss of 1.2663
# Training: Batch 48/50. Loss of 1.3358, cover loss of 0.3465, secret loss of 0.9893
# Training: Batch 49/50. Loss of 1.5248, cover loss of 0.6263, secret loss of 0.8985
# Training: Batch 50/50. Loss of 1.7428, cover loss of 0.5622, secret loss of 1.1805
# Epoch [1/3], Average_loss: 1.9599
# Training: Batch 1/50. Loss of 1.2204, cover loss of 0.2881, secret loss of 0.9323
# Training: Batch 2/50. Loss of 1.3418, cover loss of 0.1324, secret loss of 1.2095
# Training: Batch 3/50. Loss of 1.7170, cover loss of 0.4725, secret loss of 1.2445
# Training: Batch 4/50. Loss of 2.0882, cover loss of 0.3495, secret loss of 1.7387
# Training: Batch 5/50. Loss of 0.9813, cover loss of 0.2310, secret loss of 0.7502
# Training: Batch 6/50. Loss of 1.3634, cover loss of 0.3721, secret loss of 0.9913
# Training: Batch 7/50. Loss of 2.4862, cover loss of 0.4741, secret loss of 2.0121
# Training: Batch 8/50. Loss of 2.4882, cover loss of 0.2514, secret loss of 2.2368
# Training: Batch 9/50. Loss of 0.8463, cover loss of 0.2125, secret loss of 0.6338
# Training: Batch 10/50. Loss of 1.1533, cover loss of 0.2277, secret loss of 0.9255
# Training: Batch 11/50. Loss of 1.5073, cover loss of 0.4502, secret loss of 1.0571
# Training: Batch 12/50. Loss of 1.7679, cover loss of 0.2818, secret loss of 1.4861
# Training: Batch 13/50. Loss of 0.7859, cover loss of 0.1241, secret loss of 0.6618
# Training: Batch 14/50. Loss of 3.0908, cover loss of 0.2977, secret loss of 2.7931
# Training: Batch 15/50. Loss of 1.5370, cover loss of 0.3361, secret loss of 1.2010
# Training: Batch 16/50. Loss of 1.0074, cover loss of 0.3148, secret loss of 0.6927
# Training: Batch 17/50. Loss of 0.9308, cover loss of 0.3291, secret loss of 0.6018
# Training: Batch 18/50. Loss of 1.4260, cover loss of 0.2116, secret loss of 1.2145
# Training: Batch 19/50. Loss of 1.5141, cover loss of 0.1299, secret loss of 1.3842
# Training: Batch 20/50. Loss of 1.1537, cover loss of 0.2327, secret loss of 0.9210
# Training: Batch 21/50. Loss of 0.8695, cover loss of 0.3252, secret loss of 0.5443
# Training: Batch 22/50. Loss of 3.2387, cover loss of 0.1182, secret loss of 3.1205
# Training: Batch 23/50. Loss of 2.1275, cover loss of 0.2967, secret loss of 1.8308
# Training: Batch 24/50. Loss of 1.9566, cover loss of 0.5716, secret loss of 1.3850
# Training: Batch 25/50. Loss of 0.9897, cover loss of 0.2925, secret loss of 0.6972
# Training: Batch 26/50. Loss of 2.3997, cover loss of 0.1944, secret loss of 2.2054
# Training: Batch 27/50. Loss of 1.1294, cover loss of 0.1701, secret loss of 0.9593
# Training: Batch 28/50. Loss of 1.9823, cover loss of 0.2715, secret loss of 1.7107
# Training: Batch 29/50. Loss of 1.4850, cover loss of 0.2737, secret loss of 1.2114
# Training: Batch 30/50. Loss of 1.0055, cover loss of 0.0966, secret loss of 0.9089
# Training: Batch 31/50. Loss of 0.8646, cover loss of 0.2260, secret loss of 0.6386
# Training: Batch 32/50. Loss of 1.5164, cover loss of 0.3519, secret loss of 1.1645
# Training: Batch 33/50. Loss of 1.4615, cover loss of 0.3570, secret loss of 1.1045
# Training: Batch 34/50. Loss of 1.0505, cover loss of 0.3280, secret loss of 0.7225
# Training: Batch 35/50. Loss of 1.6129, cover loss of 0.4633, secret loss of 1.1496
# Training: Batch 36/50. Loss of 2.8996, cover loss of 0.2226, secret loss of 2.6770
# Training: Batch 37/50. Loss of 0.9487, cover loss of 0.2831, secret loss of 0.6656
# Training: Batch 38/50. Loss of 1.2553, cover loss of 0.1316, secret loss of 1.1237
# Training: Batch 39/50. Loss of 0.7614, cover loss of 0.1546, secret loss of 0.6068
# Training: Batch 40/50. Loss of 1.5251, cover loss of 0.2884, secret loss of 1.2367
# Training: Batch 41/50. Loss of 1.0177, cover loss of 0.1720, secret loss of 0.8457
# Training: Batch 42/50. Loss of 1.7024, cover loss of 0.1309, secret loss of 1.5715
# Training: Batch 43/50. Loss of 1.5560, cover loss of 0.4580, secret loss of 1.0980
# Training: Batch 44/50. Loss of 0.9276, cover loss of 0.2566, secret loss of 0.6710
# Training: Batch 45/50. Loss of 1.1727, cover loss of 0.3453, secret loss of 0.8274
# Training: Batch 46/50. Loss of 0.9781, cover loss of 0.1998, secret loss of 0.7783
# Training: Batch 47/50. Loss of 1.0643, cover loss of 0.6452, secret loss of 0.4191
# Training: Batch 48/50. Loss of 1.1436, cover loss of 0.2526, secret loss of 0.8910
# Training: Batch 49/50. Loss of 0.9067, cover loss of 0.3273, secret loss of 0.5794
# Training: Batch 50/50. Loss of 2.1042, cover loss of 0.3051, secret loss of 1.7991
# Epoch [2/3], Average_loss: 1.4812
# Training: Batch 1/50. Loss of 1.6405, cover loss of 0.1441, secret loss of 1.4964
# Training: Batch 2/50. Loss of 0.9049, cover loss of 0.3319, secret loss of 0.5730
# Training: Batch 3/50. Loss of 1.4610, cover loss of 0.2723, secret loss of 1.1887
# Training: Batch 4/50. Loss of 2.3948, cover loss of 0.4191, secret loss of 1.9757
# Training: Batch 5/50. Loss of 0.9786, cover loss of 0.1578, secret loss of 0.8208
# Training: Batch 6/50. Loss of 1.8340, cover loss of 0.3126, secret loss of 1.5214
# Training: Batch 7/50. Loss of 1.1649, cover loss of 0.3412, secret loss of 0.8238
# Training: Batch 8/50. Loss of 1.7270, cover loss of 0.3628, secret loss of 1.3642
# Training: Batch 9/50. Loss of 0.6553, cover loss of 0.1860, secret loss of 0.4692
# Training: Batch 10/50. Loss of 1.9550, cover loss of 0.1922, secret loss of 1.7628
# Training: Batch 11/50. Loss of 1.6592, cover loss of 0.7824, secret loss of 0.8768
# Training: Batch 12/50. Loss of 1.6580, cover loss of 0.3351, secret loss of 1.3229
# Training: Batch 13/50. Loss of 2.5725, cover loss of 0.1591, secret loss of 2.4134
# Training: Batch 14/50. Loss of 0.7876, cover loss of 0.2719, secret loss of 0.5157
# Training: Batch 15/50. Loss of 0.7446, cover loss of 0.2238, secret loss of 0.5208
# Training: Batch 16/50. Loss of 0.7713, cover loss of 0.1307, secret loss of 0.6406
# Training: Batch 17/50. Loss of 1.4006, cover loss of 0.4244, secret loss of 0.9762
# Training: Batch 18/50. Loss of 1.3989, cover loss of 0.4523, secret loss of 0.9466
# Training: Batch 19/50. Loss of 1.6469, cover loss of 0.4317, secret loss of 1.2153
# Training: Batch 20/50. Loss of 0.8141, cover loss of 0.2106, secret loss of 0.6035
# Training: Batch 21/50. Loss of 0.6698, cover loss of 0.1071, secret loss of 0.5627
# Training: Batch 22/50. Loss of 1.5264, cover loss of 0.5836, secret loss of 0.9428
# Training: Batch 23/50. Loss of 3.9479, cover loss of 0.3453, secret loss of 3.6026
# Training: Batch 24/50. Loss of 0.6539, cover loss of 0.1626, secret loss of 0.4912
# Training: Batch 25/50. Loss of 0.9231, cover loss of 0.2944, secret loss of 0.6287
# Training: Batch 26/50. Loss of 1.8341, cover loss of 0.3237, secret loss of 1.5104
# Training: Batch 27/50. Loss of 2.1669, cover loss of 0.1808, secret loss of 1.9861
# Training: Batch 28/50. Loss of 1.6117, cover loss of 0.1499, secret loss of 1.4618
# Training: Batch 29/50. Loss of 3.0924, cover loss of 0.3480, secret loss of 2.7444
# Training: Batch 30/50. Loss of 1.0491, cover loss of 0.1566, secret loss of 0.8925
# Training: Batch 31/50. Loss of 1.6725, cover loss of 0.1731, secret loss of 1.4994
# Training: Batch 32/50. Loss of 2.0021, cover loss of 0.3224, secret loss of 1.6797
# Training: Batch 33/50. Loss of 0.9757, cover loss of 0.2015, secret loss of 0.7742
# Training: Batch 34/50. Loss of 0.9652, cover loss of 0.2401, secret loss of 0.7251
# Training: Batch 35/50. Loss of 0.9528, cover loss of 0.2270, secret loss of 0.7258
# Training: Batch 36/50. Loss of 1.8716, cover loss of 0.2648, secret loss of 1.6068
# Training: Batch 37/50. Loss of 0.8221, cover loss of 0.1580, secret loss of 0.6641
# Training: Batch 38/50. Loss of 1.4415, cover loss of 0.2337, secret loss of 1.2078
# Training: Batch 39/50. Loss of 1.5405, cover loss of 0.2077, secret loss of 1.3328
# Training: Batch 40/50. Loss of 1.7607, cover loss of 0.1124, secret loss of 1.6483
# Training: Batch 41/50. Loss of 1.2348, cover loss of 0.0923, secret loss of 1.1425
# Training: Batch 42/50. Loss of 1.4321, cover loss of 0.1991, secret loss of 1.2330
# Training: Batch 43/50. Loss of 1.5900, cover loss of 0.1227, secret loss of 1.4673
# Training: Batch 44/50. Loss of 0.9458, cover loss of 0.3038, secret loss of 0.6420
# Training: Batch 45/50. Loss of 0.9163, cover loss of 0.2920, secret loss of 0.6243
# Training: Batch 46/50. Loss of 0.9310, cover loss of 0.1188, secret loss of 0.8122
# Training: Batch 47/50. Loss of 2.0662, cover loss of 0.2487, secret loss of 1.8175
# Training: Batch 48/50. Loss of 2.1090, cover loss of 0.2255, secret loss of 1.8835
# Training: Batch 49/50. Loss of 1.5725, cover loss of 0.1552, secret loss of 1.4172
# Training: Batch 50/50. Loss of 1.6531, cover loss of 0.1657, secret loss of 1.4874
# Epoch [3/3], Average_loss: 1.4820

# %%
# Plot loss through epochs
plt.plot(loss_history)
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Batch')
plt.show()

# %%
# net.load_state_dict(torch.load(MODELS_PATH+'Epoch N4.pkl'))

# Switch to evaluate mode
net.eval()

test_losses = []
# Show images
for idx, test_batch in enumerate(test_loader):
     # Saves images
    data, _ = test_batch

    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images
    test_secret = Variable(test_secret, volatile=True)
    test_cover = Variable(test_cover, volatile=True)

    # Compute output
    test_hidden, test_output = net(test_secret, test_cover)
    
    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, beta)
    
#     diff_S, diff_C = np.abs(np.array(test_output.data[0]) - np.array(test_secret.data[0])), np.abs(np.array(test_hidden.data[0]) - np.array(test_cover.data[0]))
    
#     print (diff_S, diff_C)
    
    if idx in [1,2,3,4]:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(test_loss.data, loss_secret.data, loss_cover.data))

        # Creates img tensor
        imgs = [test_secret.data, test_output.data, test_cover.data, test_hidden.data]
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)
        
    test_losses.append(test_loss.data)
        
mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
# Out:
# <ipython-input-10-1b555d2fb723>:17: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   test_secret = Variable(test_secret, volatile=True)
# <ipython-input-10-1b555d2fb723>:18: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   test_cover = Variable(test_cover, volatile=True)
# <ipython-input-3-723a443b100a>:29: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1)
# Total loss: 0.69
# Loss on secret: 0.43
# Loss on cover: 0.26
# Total loss: 1.09
# Loss on secret: 0.87
# Loss on cover: 0.22
# Average loss on test set: 1.05
